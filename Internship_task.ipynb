# %%
pip install selenium
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %% [raw]
# "https://www.contractsfinder.service.gov.uk/Search/Results"

# %% [markdown]
# ### Extracting the links, data & content from the first 100 pages:

# %%
url_pages = []
# urls_list = []
for i in range(0,101):
    url = f"https://www.contractsfinder.service.gov.uk/Search/Results?&page={i}#dashboard_notices"
    url_pages.append(url)
for m in url_pages:
    response = requests.get(m)
    page_contents = response.text
    doc = BeautifulSoup(page_contents,"html.parser")

# %%
datas = []
for i in url_pages:
    response = requests.get(i)
    page_contents = response.content
    doc = BeautifulSoup(page_contents,"html.parser")
    data = doc.find_all("div",{"class":"search-result-entry"})
    for d in data:
        datas.append(list(d.stripped_strings))

# %%
lists = []
for d in range(len(datas)):
#     for i in datas
    lists.append(datas[d][0])

# %%
lists = set(lists)
key = list(lists)
key.sort()
keys = []
for i in key:
    print(i)
    keys.append(i)
# Out:
# Approach to market date
# Closing
# Contract location
# Contract value
# Notice status
# Procurement stage
# Publication date

# %%
main_content=[]
for i in url_pages:
    response = requests.get(url)
    page_contents = response.content
    doc = BeautifulSoup(page_contents,"html.parser")
    content = doc.find_all(class_="search-result")
    print(content)
    for i in content:
        main_content.append(list(i.stripped_strings))
# Out:
# [<div class="search-result">
# <div class="search-result-header" title="Wiltshire Council Passenger Transport  DPS Sept 2017">
# <h2 id="80a311e0-4df5-434f-b81d-415cc8bd2708"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/80a311e0-4df5-434f-b81d-415cc8bd2708?origin=SearchResults&amp;p=99">Wiltshire Council Passenger Transport  DPS Sept 2017</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Wiltshire Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Wiltshire Council (the 'Council') intends to establish a Dynamic Purchasing System to improve procurement procedures to reflect best practice and to make the procurement of Passenger Transport services as efficient as possible for both the Council and suppliers.
#
# The Council's main aim is to appoint multiple suppliers to a Dynamic ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 November 2022, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £110,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 18 September 2019, last edited 11 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="London and Quadrant Housing Trust - Combined Mechanical and Electrical Dynamic Purchase System (DPS)">
# <h2 id="483ea70d-4b61-48bb-ba7e-6514b6b2b026"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/483ea70d-4b61-48bb-ba7e-6514b6b2b026?origin=SearchResults&amp;p=99">London and Quadrant Housing Trust - Combined Mechanical and Electrical Dynamic Purchase System (DPS)</a></h2> </div>
# <div class="search-result-sub-header wrap-text">L&amp;Q Construction</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">London and Quadrant Housing Trust and its subsidiary Quadrant Construction Services are one of the largest providers of affordable housing in the UK, housing over 250,000 people in more than 95,000 homes, primarily across London and the South East of England. London and Quadrant Housing Trust are tendering for the provision of works for; Combined ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 23 December 2024,  6pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> E15 4PH</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong> 23 December 2020, last edited 11 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Support to Live at Home (STLAH) Framework">
# <h2 id="afbc517b-7e64-4e0a-acc3-3c6c1672eac7"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/afbc517b-7e64-4e0a-acc3-3c6c1672eac7?origin=SearchResults&amp;p=99">Support to Live at Home (STLAH) Framework</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Barnsley Metropolitan Borough Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Barnsley Metropolitan Borough Council (the Council), is seeking to develop a Framework of Support to Live at Home Care providers. The framework is to be established to provide social care funded packages of support to adults aged 18 and over, who meet the eligibility criteria. This includes adults who have assessed care and support needs associated ...">Barnsley Metropolitan Borough Council (the Council), is seeking to develop a Framework of Support to Live at Home Care providers. The framework is to be established to provide social care funded packages of support to adults aged 18 and over, who meet the eligibility criteria. This includes adults who have assessed care and support needs associated...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 June 2027, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Yorkshire and the Humber</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0 to £60,304,305</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="PLACE060 Ad Hoc Taxi Provisions Soft Market Engagement">
# <h2 id="bdfca0d4-0d1b-4529-b325-fcaf9d2df25f"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bdfca0d4-0d1b-4529-b325-fcaf9d2df25f?origin=SearchResults&amp;p=99">PLACE060 Ad Hoc Taxi Provisions Soft Market Engagement</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Derbyshire County Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The Council wishes to hear from companies/organisations willing to share information about the possibilities for a SPA Short Term Taxi Service to gauge the likely level of interest in the project from the market. This will enable the Council to gain a better understanding of the solutions available, how they could be supplied, an indication of the ...">The Council wishes to hear from companies/organisations willing to share information about the possibilities for a SPA Short Term Taxi Service to gauge the likely level of interest in the project from the market. This will enable the Council to gain a better understanding of the solutions available, how they could be supplied, an indication of the...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Early engagement</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 10 November 2022</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022, last edited 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="CA10921 - The Ferrars Academy">
# <h2 id="3ed5ecf2-8ac5-44ed-b41f-0f8a21bcae64"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/3ed5ecf2-8ac5-44ed-b41f-0f8a21bcae64?origin=SearchResults&amp;p=99">CA10921 - The Ferrars Academy</a></h2> </div>
# <div class="search-result-sub-header wrap-text">The Ferrars Academy</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The provision of a high quality and nutritious lunch service for the pupils and staff at The Ferrars Academy.  The school is seeking a catering partner who embraces the ethos for putting the pupil and their interests at the centre of all decision making.  The value for doing the right thing will be in synergy regarding food choices and service for ...">The provision of a high quality and nutritious lunch service for the pupils and staff at The Ferrars Academy.  The school is seeking a catering partner who embraces the ethos for putting the pupil and their interests at the centre of all decision making.  The value for doing the right thing will be in synergy regarding food choices and service for...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 21 November 2022, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> LU4 0LL</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Cambridgeshire County Council Early Years Market Position Statement">
# <h2 id="436443eb-2fd3-43ac-afb5-fb835fd7421b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/436443eb-2fd3-43ac-afb5-fb835fd7421b?origin=SearchResults&amp;p=99">Cambridgeshire County Council Early Years Market Position Statement</a></h2> </div>
# <div class="search-result-sub-header wrap-text">LGSS</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The attached document sets out the priority early years and childcare developments required across Cambridgeshire. This is not an exhaustive list, other areas may require additional places; particularly where there is new housing development.
#
# All providers, regardless of their governance (e.g. childminder, private, voluntary, independent, school ...">The attached document sets out the priority early years and childcare developments required across Cambridgeshire. This is not an exhaustive list, other areas may require additional places; particularly where there is new housing development.
#
# All providers, regardless of their governance (e.g. childminder, private, voluntary, independent, school...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Early engagement</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 31 March 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> East of England</div>
# <div class="search-result-entry"><strong>Publication date</strong> 29 March 2022, last edited  9 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="FCA Service Desk and End User Compute (EUC) Services">
# <h2 id="d81dad03-63ac-4d4a-8577-11e5513d55fe"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/d81dad03-63ac-4d4a-8577-11e5513d55fe?origin=SearchResults&amp;p=99">FCA Service Desk and End User Compute (EUC) Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Financial Conduct Authority</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">The Financial Conduct Authority is undergoing a digital transformation journey to implement a more focused, responsive and customer centric SD (Service Desk) and EUC solution, with the aim to transform and migrate services to the cloud where possible.
#
#       With the ongoing transformation, the Financial Conduct Authority are looking for a ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 June 2023, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £105,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  9 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Tourniquet">
# <h2 id="453bcd8a-21d6-4844-8ad3-4e27f96a7665"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/453bcd8a-21d6-4844-8ad3-4e27f96a7665?origin=SearchResults&amp;p=99">Tourniquet</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS Supply Chain</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">The agreement will cover the following product types:  Single Use Tourniquets: Band Type, Button, Quick Release Pull Through types and Resuable Tourniquets. Precise quantities are unknown. It is anticipated that initial expenditure is estimated to be in the region of 3,030,000 - £4,545,000 in the first year of this Framework Agreement, and the ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong> 14 March 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> North East, North West, Yorkshire and the Humber, East Midlands, West Midlands, East of England, London, South East, South West</div>
# <div class="search-result-entry"><strong>Contract value</strong> £18,180,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  8 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Expression of Interest - CIRAS Reporting App">
# <h2 id="a24e9839-5bfb-4cbe-92ad-40dbeec5532b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/a24e9839-5bfb-4cbe-92ad-40dbeec5532b?origin=SearchResults&amp;p=99">Expression of Interest - CIRAS Reporting App</a></h2> </div>
# <div class="search-result-sub-header wrap-text">BIP SOLUTIONS LIMITED</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Rail Safety and Standards Board (RSSB) seeks to obtain market feedback in relation to the high-level business requirements for the CIRAS Reporting App for its subsidiary Confidential Incident Reporting &amp; Analysis Service Ltd. Please respond to the questions in the Expression of Interest (EOI) document.  Deadline for EOI submission is 1700 hours on ...">Rail Safety and Standards Board (RSSB) seeks to obtain market feedback in relation to the high-level business requirements for the CIRAS Reporting App for its subsidiary Confidential Incident Reporting &amp; Analysis Service Ltd. Please respond to the questions in the Expression of Interest (EOI) document.  Deadline for EOI submission is 1700 hours on...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 14 November 2022, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom, Isle of Man, Channel Islands, British Oversea Territories, Europe, Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong>  5 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Centre for Advancing Practice Portal Development 23-28">
# <h2 id="bdbed967-4945-4642-aae2-8e4bae8e1448"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bdbed967-4945-4642-aae2-8e4bae8e1448?origin=SearchResults&amp;p=99">Centre for Advancing Practice Portal Development 23-28</a></h2> </div>
# <div class="search-result-sub-header wrap-text">HEE</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">HEE is seeking a provider to add additional functionality to the Centre for Advancing Practice portal which facilitates the upload and evaluation of portfolios of evidence.</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 31 March 2023, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £330,000 to £330,000.01</div>
# <div class="search-result-entry"><strong>Publication date</strong>  4 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Postal Services &amp; Solutions">
# <h2 id="4bebd88d-ac2f-4ce4-a763-2bad66a39be5"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/4bebd88d-ac2f-4ce4-a763-2bad66a39be5?origin=SearchResults&amp;p=99">Postal Services &amp; Solutions</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Crown Commercial Service</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Crown Commercial Service (CCS) as the Authority intends to put in place a Pan Government Collaborative Agreement for the provision of postal services and solutions to be utilised by Central Government Departments and all other UK Public Sector Bodies, including Local Authorities, Health, Police, Fire and Rescue, Education and Devolved ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong> 22 February 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £1,600,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  4 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="North Forest District Planting and Forest Management DPS">
# <h2 id="d20ae626-57f7-476d-9a66-91c5fe2d0c17"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/d20ae626-57f7-476d-9a66-91c5fe2d0c17?origin=SearchResults&amp;p=99">North Forest District Planting and Forest Management DPS</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Forestry England</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="North England Forest District (NEFD) encompasses Northumberland, County Durham, Cumbria and North Lancashire. The District Office is based at Bellingham, with 7 outstation offices located across the District. The Forest District has an average current annual restock programme of between 750- 900Ha.
#       Forestry England will be awarding contracts ...">North England Forest District (NEFD) encompasses Northumberland, County Durham, Cumbria and North Lancashire. The District Office is based at Bellingham, with 7 outstation offices located across the District. The Forest District has an average current annual restock programme of between 750- 900Ha.
#       Forestry England will be awarding contracts...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong>  2 August 2030, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £10,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  3 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin">
# <h2 id="986e5e89-4eb5-45dc-8098-ed5508ac0991"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/986e5e89-4eb5-45dc-8098-ed5508ac0991?origin=SearchResults&amp;p=99">NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS ENGLAND</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin
#
# The purpose of this 'future opportunity' notice is to indicate that a live 'opportunity' may be published at a future date.  However, any existing 'live' framework agreement may be subject to an extension up to the maximum extension period allowedHuman Normal ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 February 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> England, Scotland, Northern Ireland, Isle of Man, Channel Islands</div>
# <div class="search-result-entry"><strong>Contract value</strong> £526,598,540</div>
# <div class="search-result-entry"><strong>Publication date</strong> 17 March 2022, last edited  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin">
# <h2 id="ba54be46-877e-4f98-a557-6079ad634ec3"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/ba54be46-877e-4f98-a557-6079ad634ec3?origin=SearchResults&amp;p=99">NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS ENGLAND</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin
#
# The purpose of this 'future opportunity' notice is to indicate that a live 'opportunity' may be published at a future date.  However, any existing 'live' framework agreement may be subject to an extension up to the maximum extension period allowed.</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 August 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> England, Scotland, Northern Ireland, Isle of Man, Channel Islands</div>
# <div class="search-result-entry"><strong>Contract value</strong> £526,598,540</div>
# <div class="search-result-entry"><strong>Publication date</strong> 14 September 2021, last edited  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Fresh Food DPS">
# <h2 id="b1df324f-40a7-45a1-85e1-e053f14a856c"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/b1df324f-40a7-45a1-85e1-e053f14a856c?origin=SearchResults&amp;p=99">Fresh Food DPS</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS Supply Chain</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Due to a technical issue the dates above do not represent the actual DPS Contract Dates.
#
# 2022/S 000-020877
#
# NHS Supply Chain: Food seeks to establish a non-exclusive DPS Agreement for the supply of Fresh Food to NHS Supply Chain: Food's customer base via the Direct Route covering products including but not limited to: fruit, vegetables, ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 28 February 2029,  3pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £200,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="The Micromobility Market and London's Micromobility Future">
# <h2 id="a8d0809b-eea9-41b6-9cab-e2bf3bb2635b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/a8d0809b-eea9-41b6-9cab-e2bf3bb2635b?origin=SearchResults&amp;p=99">The Micromobility Market and London's Micromobility Future</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Transport for London</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">TfL wishes to seek your views on the extent of your understanding of opportunities in micromobility rental in London and views on what London's micromobility future might look like.
#
# TfL would appreciate your feedback in the form of a response to any relevant or applicable sections to your organisation in this questionnaire
#
# This exercise ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 April 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong>  1 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="DPS - Dynamic Supplier List: Asset Solutions">
# <h2 id="70b9ebf0-652e-48c0-be32-d1bba404ca50"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/70b9ebf0-652e-48c0-be32-d1bba404ca50?origin=SearchResults&amp;p=99">DPS - Dynamic Supplier List: Asset Solutions</a></h2> </div>
# <div class="search-result-sub-header wrap-text">EASTERN PROCUREMENT LIMITED</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Dear Contractor Thank you for your interest in this Dynamic Supplier List for Asset Solutions opportunity, run by Eastern Procurement Limited (EP). The concept of this agreement is one that is likely to be familiar to you. We are creating an approved suppliers list, covering a number of commodities, to both the housing sector and the public sector ...">Dear Contractor Thank you for your interest in this Dynamic Supplier List for Asset Solutions opportunity, run by Eastern Procurement Limited (EP). The concept of this agreement is one that is likely to be familiar to you. We are creating an approved suppliers list, covering a number of commodities, to both the housing sector and the public sector...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 29 November 2025, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom, Isle of Man, Channel Islands, British Oversea Territories, Europe, Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £210,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 18 April 2019, last edited 29 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="628_23 Security and Surveillance Equipment and Services">
# <h2 id="bee25f67-074c-4ef0-9a01-c25e24e445fa"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bee25f67-074c-4ef0-9a01-c25e24e445fa?origin=SearchResults&amp;p=99">628_23 Security and Surveillance Equipment and Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Espo</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Please note this is a Prior Information Notice and the tender documentation is not available yet.
#
# An ESPO national framework which covers a range of security and surveillance solutions including public and private space CCTV, access control, intruder detection, independent security consultancy, ANPR cameras and body worn cameras.
#
# Lot 1 - ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  6 January 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £100,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 29 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Adult Learning Classroom Provision 2022 - 2025">
# <h2 id="cf0d358a-d93f-4f92-a585-d56bbf077881"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/cf0d358a-d93f-4f92-a585-d56bbf077881?origin=SearchResults&amp;p=99">Adult Learning Classroom Provision 2022 - 2025</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Wirral Borough Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Wirral Council's Adult Learning Service is looking to procure a core of teaching facilities (classrooms) in the Birkenhead area , plus flexible response community / outreach venues in other wards to support delivery of a wide range of adult learning courses from basic English and maths to floristry and textiles.</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  2 June 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £500,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 27 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Mobile Telephony Services">
# <h2 id="c7c3d17f-7a81-4950-8a3d-7148ba93ae6a"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/c7c3d17f-7a81-4950-8a3d-7148ba93ae6a?origin=SearchResults&amp;p=99">Mobile Telephony Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Croydon Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Mobile Telephony Contract</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 August 2024</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £100,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 27 July 2022</div>
# </div>]
# [<div class="search-result">
# <div class="search-result-header" title="Wiltshire Council Passenger Transport  DPS Sept 2017">
# <h2 id="80a311e0-4df5-434f-b81d-415cc8bd2708"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/80a311e0-4df5-434f-b81d-415cc8bd2708?origin=SearchResults&amp;p=99">Wiltshire Council Passenger Transport  DPS Sept 2017</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Wiltshire Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Wiltshire Council (the 'Council') intends to establish a Dynamic Purchasing System to improve procurement procedures to reflect best practice and to make the procurement of Passenger Transport services as efficient as possible for both the Council and suppliers.
#
# The Council's main aim is to appoint multiple suppliers to a Dynamic ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 November 2022, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £110,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 18 September 2019, last edited 11 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="London and Quadrant Housing Trust - Combined Mechanical and Electrical Dynamic Purchase System (DPS)">
# <h2 id="483ea70d-4b61-48bb-ba7e-6514b6b2b026"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/483ea70d-4b61-48bb-ba7e-6514b6b2b026?origin=SearchResults&amp;p=99">London and Quadrant Housing Trust - Combined Mechanical and Electrical Dynamic Purchase System (DPS)</a></h2> </div>
# <div class="search-result-sub-header wrap-text">L&amp;Q Construction</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">London and Quadrant Housing Trust and its subsidiary Quadrant Construction Services are one of the largest providers of affordable housing in the UK, housing over 250,000 people in more than 95,000 homes, primarily across London and the South East of England. London and Quadrant Housing Trust are tendering for the provision of works for; Combined ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 23 December 2024,  6pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> E15 4PH</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong> 23 December 2020, last edited 11 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Support to Live at Home (STLAH) Framework">
# <h2 id="afbc517b-7e64-4e0a-acc3-3c6c1672eac7"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/afbc517b-7e64-4e0a-acc3-3c6c1672eac7?origin=SearchResults&amp;p=99">Support to Live at Home (STLAH) Framework</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Barnsley Metropolitan Borough Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Barnsley Metropolitan Borough Council (the Council), is seeking to develop a Framework of Support to Live at Home Care providers. The framework is to be established to provide social care funded packages of support to adults aged 18 and over, who meet the eligibility criteria. This includes adults who have assessed care and support needs associated ...">Barnsley Metropolitan Borough Council (the Council), is seeking to develop a Framework of Support to Live at Home Care providers. The framework is to be established to provide social care funded packages of support to adults aged 18 and over, who meet the eligibility criteria. This includes adults who have assessed care and support needs associated...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 June 2027, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Yorkshire and the Humber</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0 to £60,304,305</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="PLACE060 Ad Hoc Taxi Provisions Soft Market Engagement">
# <h2 id="bdfca0d4-0d1b-4529-b325-fcaf9d2df25f"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bdfca0d4-0d1b-4529-b325-fcaf9d2df25f?origin=SearchResults&amp;p=99">PLACE060 Ad Hoc Taxi Provisions Soft Market Engagement</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Derbyshire County Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The Council wishes to hear from companies/organisations willing to share information about the possibilities for a SPA Short Term Taxi Service to gauge the likely level of interest in the project from the market. This will enable the Council to gain a better understanding of the solutions available, how they could be supplied, an indication of the ...">The Council wishes to hear from companies/organisations willing to share information about the possibilities for a SPA Short Term Taxi Service to gauge the likely level of interest in the project from the market. This will enable the Council to gain a better understanding of the solutions available, how they could be supplied, an indication of the...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Early engagement</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 10 November 2022</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022, last edited 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="CA10921 - The Ferrars Academy">
# <h2 id="3ed5ecf2-8ac5-44ed-b41f-0f8a21bcae64"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/3ed5ecf2-8ac5-44ed-b41f-0f8a21bcae64?origin=SearchResults&amp;p=99">CA10921 - The Ferrars Academy</a></h2> </div>
# <div class="search-result-sub-header wrap-text">The Ferrars Academy</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The provision of a high quality and nutritious lunch service for the pupils and staff at The Ferrars Academy.  The school is seeking a catering partner who embraces the ethos for putting the pupil and their interests at the centre of all decision making.  The value for doing the right thing will be in synergy regarding food choices and service for ...">The provision of a high quality and nutritious lunch service for the pupils and staff at The Ferrars Academy.  The school is seeking a catering partner who embraces the ethos for putting the pupil and their interests at the centre of all decision making.  The value for doing the right thing will be in synergy regarding food choices and service for...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 21 November 2022, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> LU4 0LL</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong> 10 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Cambridgeshire County Council Early Years Market Position Statement">
# <h2 id="436443eb-2fd3-43ac-afb5-fb835fd7421b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/436443eb-2fd3-43ac-afb5-fb835fd7421b?origin=SearchResults&amp;p=99">Cambridgeshire County Council Early Years Market Position Statement</a></h2> </div>
# <div class="search-result-sub-header wrap-text">LGSS</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="The attached document sets out the priority early years and childcare developments required across Cambridgeshire. This is not an exhaustive list, other areas may require additional places; particularly where there is new housing development.
#
# All providers, regardless of their governance (e.g. childminder, private, voluntary, independent, school ...">The attached document sets out the priority early years and childcare developments required across Cambridgeshire. This is not an exhaustive list, other areas may require additional places; particularly where there is new housing development.
#
# All providers, regardless of their governance (e.g. childminder, private, voluntary, independent, school...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Early engagement</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 31 March 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> East of England</div>
# <div class="search-result-entry"><strong>Publication date</strong> 29 March 2022, last edited  9 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="FCA Service Desk and End User Compute (EUC) Services">
# <h2 id="d81dad03-63ac-4d4a-8577-11e5513d55fe"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/d81dad03-63ac-4d4a-8577-11e5513d55fe?origin=SearchResults&amp;p=99">FCA Service Desk and End User Compute (EUC) Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Financial Conduct Authority</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">The Financial Conduct Authority is undergoing a digital transformation journey to implement a more focused, responsive and customer centric SD (Service Desk) and EUC solution, with the aim to transform and migrate services to the cloud where possible.
#
#       With the ongoing transformation, the Financial Conduct Authority are looking for a ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 30 June 2023, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £105,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  9 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Tourniquet">
# <h2 id="453bcd8a-21d6-4844-8ad3-4e27f96a7665"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/453bcd8a-21d6-4844-8ad3-4e27f96a7665?origin=SearchResults&amp;p=99">Tourniquet</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS Supply Chain</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">The agreement will cover the following product types:  Single Use Tourniquets: Band Type, Button, Quick Release Pull Through types and Resuable Tourniquets. Precise quantities are unknown. It is anticipated that initial expenditure is estimated to be in the region of 3,030,000 - £4,545,000 in the first year of this Framework Agreement, and the ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong> 14 March 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> North East, North West, Yorkshire and the Humber, East Midlands, West Midlands, East of England, London, South East, South West</div>
# <div class="search-result-entry"><strong>Contract value</strong> £18,180,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  8 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Expression of Interest - CIRAS Reporting App">
# <h2 id="a24e9839-5bfb-4cbe-92ad-40dbeec5532b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/a24e9839-5bfb-4cbe-92ad-40dbeec5532b?origin=SearchResults&amp;p=99">Expression of Interest - CIRAS Reporting App</a></h2> </div>
# <div class="search-result-sub-header wrap-text">BIP SOLUTIONS LIMITED</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Rail Safety and Standards Board (RSSB) seeks to obtain market feedback in relation to the high-level business requirements for the CIRAS Reporting App for its subsidiary Confidential Incident Reporting &amp; Analysis Service Ltd. Please respond to the questions in the Expression of Interest (EOI) document.  Deadline for EOI submission is 1700 hours on ...">Rail Safety and Standards Board (RSSB) seeks to obtain market feedback in relation to the high-level business requirements for the CIRAS Reporting App for its subsidiary Confidential Incident Reporting &amp; Analysis Service Ltd. Please respond to the questions in the Expression of Interest (EOI) document.  Deadline for EOI submission is 1700 hours on...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 14 November 2022, 12am</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom, Isle of Man, Channel Islands, British Oversea Territories, Europe, Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong>  5 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Centre for Advancing Practice Portal Development 23-28">
# <h2 id="bdbed967-4945-4642-aae2-8e4bae8e1448"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bdbed967-4945-4642-aae2-8e4bae8e1448?origin=SearchResults&amp;p=99">Centre for Advancing Practice Portal Development 23-28</a></h2> </div>
# <div class="search-result-sub-header wrap-text">HEE</div>
# <div class="search-result-spacer"> </div>
# ...
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 31 March 2023, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £330,000 to £330,000.01</div>
# <div class="search-result-entry"><strong>Publication date</strong>  4 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Postal Services &amp; Solutions">
# <h2 id="4bebd88d-ac2f-4ce4-a763-2bad66a39be5"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/4bebd88d-ac2f-4ce4-a763-2bad66a39be5?origin=SearchResults&amp;p=99">Postal Services &amp; Solutions</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Crown Commercial Service</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Crown Commercial Service (CCS) as the Authority intends to put in place a Pan Government Collaborative Agreement for the provision of postal services and solutions to be utilised by Central Government Departments and all other UK Public Sector Bodies, including Local Authorities, Health, Police, Fire and Rescue, Education and Devolved ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong> 22 February 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £1,600,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  4 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="North Forest District Planting and Forest Management DPS">
# <h2 id="d20ae626-57f7-476d-9a66-91c5fe2d0c17"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/d20ae626-57f7-476d-9a66-91c5fe2d0c17?origin=SearchResults&amp;p=99">North Forest District Planting and Forest Management DPS</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Forestry England</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="North England Forest District (NEFD) encompasses Northumberland, County Durham, Cumbria and North Lancashire. The District Office is based at Bellingham, with 7 outstation offices located across the District. The Forest District has an average current annual restock programme of between 750- 900Ha.
#       Forestry England will be awarding contracts ...">North England Forest District (NEFD) encompasses Northumberland, County Durham, Cumbria and North Lancashire. The District Office is based at Bellingham, with 7 outstation offices located across the District. The Forest District has an average current annual restock programme of between 750- 900Ha.
#       Forestry England will be awarding contracts...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong>  2 August 2030, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £10,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  3 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin">
# <h2 id="986e5e89-4eb5-45dc-8098-ed5508ac0991"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/986e5e89-4eb5-45dc-8098-ed5508ac0991?origin=SearchResults&amp;p=99">NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS ENGLAND</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin
#
# The purpose of this 'future opportunity' notice is to indicate that a live 'opportunity' may be published at a future date.  However, any existing 'live' framework agreement may be subject to an extension up to the maximum extension period allowedHuman Normal ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 February 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> England, Scotland, Northern Ireland, Isle of Man, Channel Islands</div>
# <div class="search-result-entry"><strong>Contract value</strong> £526,598,540</div>
# <div class="search-result-entry"><strong>Publication date</strong> 17 March 2022, last edited  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin">
# <h2 id="ba54be46-877e-4f98-a557-6079ad634ec3"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/ba54be46-877e-4f98-a557-6079ad634ec3?origin=SearchResults&amp;p=99">NHS Framework Agreement for the Supply of Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS ENGLAND</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Human Normal Immunoglobulin &amp; Anti-D Immunoglobulin
#
# The purpose of this 'future opportunity' notice is to indicate that a live 'opportunity' may be published at a future date.  However, any existing 'live' framework agreement may be subject to an extension up to the maximum extension period allowed.</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 August 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> England, Scotland, Northern Ireland, Isle of Man, Channel Islands</div>
# <div class="search-result-entry"><strong>Contract value</strong> £526,598,540</div>
# <div class="search-result-entry"><strong>Publication date</strong> 14 September 2021, last edited  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Fresh Food DPS">
# <h2 id="b1df324f-40a7-45a1-85e1-e053f14a856c"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/b1df324f-40a7-45a1-85e1-e053f14a856c?origin=SearchResults&amp;p=99">Fresh Food DPS</a></h2> </div>
# <div class="search-result-sub-header wrap-text">NHS Supply Chain</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Due to a technical issue the dates above do not represent the actual DPS Contract Dates.
#
# 2022/S 000-020877
#
# NHS Supply Chain: Food seeks to establish a non-exclusive DPS Agreement for the supply of Fresh Food to NHS Supply Chain: Food's customer base via the Direct Route covering products including but not limited to: fruit, vegetables, ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 28 February 2029,  3pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> Any region</div>
# <div class="search-result-entry"><strong>Contract value</strong> £200,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong>  2 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="The Micromobility Market and London's Micromobility Future">
# <h2 id="a8d0809b-eea9-41b6-9cab-e2bf3bb2635b"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/a8d0809b-eea9-41b6-9cab-e2bf3bb2635b?origin=SearchResults&amp;p=99">The Micromobility Market and London's Micromobility Future</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Transport for London</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">TfL wishes to seek your views on the extent of your understanding of opportunities in micromobility rental in London and views on what London's micromobility future might look like.
#
# TfL would appreciate your feedback in the form of a response to any relevant or applicable sections to your organisation in this questionnaire
#
# This exercise ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 April 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £0</div>
# <div class="search-result-entry"><strong>Publication date</strong>  1 August 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="DPS - Dynamic Supplier List: Asset Solutions">
# <h2 id="70b9ebf0-652e-48c0-be32-d1bba404ca50"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/70b9ebf0-652e-48c0-be32-d1bba404ca50?origin=SearchResults&amp;p=99">DPS - Dynamic Supplier List: Asset Solutions</a></h2> </div>
# <div class="search-result-sub-header wrap-text">EASTERN PROCUREMENT LIMITED</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text"><span title="Dear Contractor Thank you for your interest in this Dynamic Supplier List for Asset Solutions opportunity, run by Eastern Procurement Limited (EP). The concept of this agreement is one that is likely to be familiar to you. We are creating an approved suppliers list, covering a number of commodities, to both the housing sector and the public sector ...">Dear Contractor Thank you for your interest in this Dynamic Supplier List for Asset Solutions opportunity, run by Eastern Procurement Limited (EP). The concept of this agreement is one that is likely to be familiar to you. We are creating an approved suppliers list, covering a number of commodities, to both the housing sector and the public sector...</span></div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Closing</strong> 29 November 2025, 12pm</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom, Isle of Man, Channel Islands, British Oversea Territories, Europe, Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £210,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 18 April 2019, last edited 29 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="628_23 Security and Surveillance Equipment and Services">
# <h2 id="bee25f67-074c-4ef0-9a01-c25e24e445fa"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/bee25f67-074c-4ef0-9a01-c25e24e445fa?origin=SearchResults&amp;p=99">628_23 Security and Surveillance Equipment and Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Espo</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Please note this is a Prior Information Notice and the tender documentation is not available yet.
#
# An ESPO national framework which covers a range of security and surveillance solutions including public and private space CCTV, access control, intruder detection, independent security consultancy, ANPR cameras and body worn cameras.
#
# Lot 1 - ...</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  6 January 2023</div>
# <div class="search-result-entry"><strong>Contract location</strong> United Kingdom</div>
# <div class="search-result-entry"><strong>Contract value</strong> £100,000,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 29 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Adult Learning Classroom Provision 2022 - 2025">
# <h2 id="cf0d358a-d93f-4f92-a585-d56bbf077881"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/cf0d358a-d93f-4f92-a585-d56bbf077881?origin=SearchResults&amp;p=99">Adult Learning Classroom Provision 2022 - 2025</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Wirral Borough Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Wirral Council's Adult Learning Service is looking to procure a core of teaching facilities (classrooms) in the Birkenhead area , plus flexible response community / outreach venues in other wards to support delivery of a wide range of adult learning courses from basic English and maths to floristry and textiles.</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  2 June 2025</div>
# <div class="search-result-entry"><strong>Contract location</strong> Rest of the World</div>
# <div class="search-result-entry"><strong>Contract value</strong> £500,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 27 July 2022</div>
# </div>, <div class="search-result">
# <div class="search-result-header" title="Mobile Telephony Services">
# <h2 id="c7c3d17f-7a81-4950-8a3d-7148ba93ae6a"><a class="govuk-link search-result-rwh break-word" data-page="99" href="https://www.contractsfinder.service.gov.uk/notice/c7c3d17f-7a81-4950-8a3d-7148ba93ae6a?origin=SearchResults&amp;p=99">Mobile Telephony Services</a></h2> </div>
# <div class="search-result-sub-header wrap-text">Croydon Council</div>
# <div class="search-result-spacer"> </div>
# <div class="wrap-text">Mobile Telephony Contract</div>
# <div class="search-result-spacer"> </div>
# <div class="search-result-entry"><strong>Procurement stage</strong> Future opportunity</div>
# <div class="search-result-entry"><strong>Notice status</strong> Open</div>
# <div class="search-result-entry"><strong>Approach to market date</strong>  1 August 2024</div>
# <div class="search-result-entry"><strong>Contract location</strong> England</div>
# <div class="search-result-entry"><strong>Contract value</strong> £100,000</div>
# <div class="search-result-entry"><strong>Publication date</strong> 27 July 2022</div>
# </div>]

# %%
Heading = []
Sub_heading = []
for m in main_content:
    Heading.append(m[0])
    Sub_heading.append(m[1])

# %%
Approach_to_market_date = []
Closing = []
Contract_location = []
Contract_value = []
Notice_status = []
Procurement_stage = []
Publication_date = []
for m in main_content:
    if keys[0]in m:
        iloc = m.index(keys[0])+1
        Approach_to_market_date.append(m[iloc])
    else:
        Approach_to_market_date.append(np.nan)
    if keys[1]in m:
        iloc = m.index(keys[1])+1
        Closing.append(m[iloc])
    else:
        Closing.append(np.nan)
    if keys[2]in m:
        iloc = m.index(keys[2])+1
        Contract_location.append(m[iloc])
    else:
        Contract_location.append(np.nan)
    if keys[3]in m:
        iloc = m.index(keys[3])+1
        Contract_value.append(m[iloc])
    else:
        Contract_value.append(np.nan)
    if keys[4]in m:
        iloc = m.index(keys[4])+1
        Notice_status.append(m[iloc])
    else:
        Notice_status.append(np.nan)
    if keys[5]in m:
        iloc = m.index(keys[5])+1
        Procurement_stage.append(m[iloc])
    else:
        Procurement_stage.append(np.nan)
    if keys[6]in m:
        iloc = m.index(keys[6])+1
        Publication_date.append(m[iloc])
    else:
        Publication_date.append(np.nan)

# %% [markdown]
# ### Creating a DataFrame

# %%
df = pd.DataFrame({"Heading":Heading,"Sub_Heading":Sub_heading,"Closing":Closing,"Notice_status":Notice_status,"Contract_location":Contract_location,"Contract_value":Contract_value,"Publication_date":Publication_date,"Procurement_stage":Procurement_stage,"Approach_to_market_date":Approach_to_market_date})

# %% [markdown]
# ### Converting Approach_to_market_date, Closing, Publication_date into datetime

# %%
df["Approach_to_market_date"] = pd.to_datetime(df["Approach_to_market_date"])

# %%
df["Closing"] = pd.to_datetime(df["Closing"])

# %%
for i in range(len(df["Publication_date"])):
    df["Publication_date"][i]=df["Publication_date"][i].split(",")[0]
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_6236/1600369674.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Publication_date"][i]=df["Publication_date"][i].split(",")[0]

# %%
df["Publication_date"] = pd.to_datetime(df["Publication_date"])

# %% [markdown]
# ### Converting Contract_value from object to float

# %%
vals = []
for i in df["Contract_value"]:
    if type(i)!=float:
        x = i.replace("£","")
        z = x.replace(",","")
        y = z.split("to")
        num_list = []
        for num in y:
            num_list.append(float(num))
        vals.append((sum(num_list)/len(num_list)))
    else:
        vals.append(i)

# %%
df["Contract_value"]=vals

# %%
df.head(10)
# Out:
#                                              Heading  \
# 0  Wiltshire Council Passenger Transport  DPS Sep...
# 1  London and Quadrant Housing Trust - Combined M...
# 2          Support to Live at Home (STLAH) Framework
# 3  PLACE060 Ad Hoc Taxi Provisions Soft Market En...
# 4                      CA10921 - The Ferrars Academy
# 5  Cambridgeshire County Council Early Years Mark...
# 6  FCA Service Desk and End User Compute (EUC) Se...
# 7                                         Tourniquet
# 8       Expression of Interest - CIRAS Reporting App
# 9  Centre for Advancing Practice Portal Developme...
#
#                              Sub_Heading             Closing Notice_status  \
# 0                      Wiltshire Council 2022-11-30 00:00:00          Open
# 1                       L&Q Construction 2024-12-23 18:00:00          Open
# 2  Barnsley Metropolitan Borough Council 2027-06-30 12:00:00          Open
# 3              Derbyshire County Council 2022-11-10 00:00:00          Open
# 4                    The Ferrars Academy 2022-11-21 12:00:00          Open
# 5                                   LGSS 2023-03-31 00:00:00          Open
# 6            Financial Conduct Authority 2023-06-30 00:00:00          Open
# 7                       NHS Supply Chain                 NaT          Open
# 8                  BIP SOLUTIONS LIMITED 2022-11-14 00:00:00          Open
# 9                                    HEE 2023-03-31 12:00:00          Open
#
#                                    Contract_location  Contract_value  \
# 0                                            England    1.100000e+08
# 1                                            E15 4PH    0.000000e+00
# 2                           Yorkshire and the Humber    3.015215e+07
# 3                                            England             NaN
# 4                                            LU4 0LL    0.000000e+00
# 5                                    East of England             NaN
# 6                                         Any region    1.050000e+08
# 7  North East, North West, Yorkshire and the Humb...    1.818000e+07
# 8  United Kingdom, Isle of Man, Channel Islands, ...    0.000000e+00
# 9                                     United Kingdom    3.300000e+05
#
#   Publication_date   Procurement_stage Approach_to_market_date
# 0       2019-09-18         Opportunity                     NaT
# 1       2020-12-23         Opportunity                     NaT
# 2       2022-08-10         Opportunity                     NaT
# 3       2022-08-10    Early engagement                     NaT
# 4       2022-08-10         Opportunity                     NaT
# 5       2022-03-29    Early engagement                     NaT
# 6       2022-08-09         Opportunity                     NaT
# 7       2022-08-08  Future opportunity              2023-03-14
# 8       2022-08-05         Opportunity                     NaT
# 9       2022-08-04         Opportunity                     NaT

# %% [markdown]
# ### Data Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(17,15))
ax = sns.barplot(x = "Contract_location",y = "Contract_value" ,hue="Procurement_stage",data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(17,15))
ax = sns.countplot(x = "Contract_location",hue="Procurement_stage",data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
df.head(1)
# Out:
#                                              Heading        Sub_Heading  \
# 0  Wiltshire Council Passenger Transport  DPS Sep...  Wiltshire Council
#
#      Closing Notice_status Contract_location  Contract_value Publication_date  \
# 0 2022-11-30          Open           England     110000000.0       2019-09-18
#
#   Procurement_stage Approach_to_market_date
# 0       Opportunity                     NaT

# %%
fig,ax = plt.subplots(figsize=(20,5))

sns.kdeplot(df[df["Procurement_stage"]=="Opportunity"]["Closing"], shade=True, color="blue", label="Opportunity",ax=ax)
sns.kdeplot(df[df["Procurement_stage"]=="Future Opportunity"]["Closing"], shade=True, color="green", label="Future Opportunity",ax=ax)
sns.kdeplot(df[df["Procurement_stage"]=="Early engagement"]["Closing"], shade=True, color="red", label="Early engagement",ax=ax)

ax.set_xlabel("Closing")
ax.set_ylabel("Counts")

fig.suptitle("Closing vs. Procurement stage")

ax.legend();

# %% [markdown]
# ### Saving Dataframe to CSV

# %%
df.to_csv("Internship_task.csv")
